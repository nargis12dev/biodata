# %%
#program to take the required input for students biodata
first_name=input("enter your first name:")
last_name=input("enter your last name:")
father_name=input("entere your father name:")
age=input("enter your age:")
roll_no=input("enter your roll no:")
program_enrolled=input("enter program enrollment:")
university_name=input("enter your university name:")

#generating biodata
print("---biodata---")
print("your biodata is as follow")
student_biodata=("your name is" + first_name + " " + last_name + " your age is "
                  + age + "your roll no is" + roll_no + "and you are studying in the university" + university_name + "enrolled in the program"
                    + program_enrolled)
print(student_biodata)
